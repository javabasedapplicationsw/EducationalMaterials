# %%
import pandas as pd

# %% [markdown]
# ### 데이터프레임의 변수별 계산
#   - 변수별 합, 평균, 중앙값, 분산, 표준편차 등 통계함수
#   - sum(), mean(), median(), var(), std()

# %%
file_url = 'sample_df.csv'

# %%
sample_df = pd.read_csv(file_url, index_col=0)

# %%
sample_df
# Out:
#    var_1  var_2  var_3  var_4  var_5
# a      2      2      1      4      3
# b      4      3      3      7      1
# c      5      4      6      3      5
# d      1      4      5      6      7
# e      4      5      7      8      3
# f      5      4      8      9      4
# g      7      5      2      0      6
# h      8      8      1      7      8
# i      2      3      5      2      1
# j      9      3      7      6      5

# %%
sample_df.sum()
# Out:
# var_1    47
# var_2    41
# var_3    45
# var_4    52
# var_5    43
# dtype: int64

# %%
# 변수별 합과 평균을 출력하시오
# aggregate() 함수의 괄호 안에 sum, mean을 입력하면 됨
# 단, 하나의 값으로 입력되도록 리슽크로 묶어주어야 함
sample_df.aggregate(['sum', 'mean'])
# Out:
#       var_1  var_2  var_3  var_4  var_5
# sum    47.0   41.0   45.0   52.0   43.0
# mean    4.7    4.1    4.5    5.2    4.3

# %% [markdown]
# ### iris.csv
#   - 붓꽃의 종마다 꽃받침과 꽃잎 크기가 어떻게 다른지를 보여주는 데이터임

# %%
file_url = 'iris.csv'
iris = pd.read_csv(file_url)

# %%
iris
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  6.1               3.0                4.6               1.4
# 1                  7.2               3.0                5.8               1.6
# 2                  6.7               3.1                4.4               1.4
# 3                  6.2               2.9                4.3               1.3
# 4                  4.6               3.4                1.4               0.3
# ..                 ...               ...                ...               ...
# 145                5.7               2.5                5.0               2.0
# 146                6.3               2.9                5.6               1.8
# 147                6.8               3.2                5.9               2.3
# 148                6.1               2.8                4.7               1.2
# 149                5.1               2.5                3.0               1.1
#
#           class
# ...

# %%
iris.head()
'''
class
  - 붓꽃(iris)의 종류
  - versicolor, virginica, setosa
sepal(꽃받침)의 길이와 너비
petal(꽃잎)의 길이와 너비
'''
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                6.1               3.0                4.6               1.4
# 1                7.2               3.0                5.8               1.6
# 2                6.7               3.1                4.4               1.4
# 3                6.2               2.9                4.3               1.3
# 4                4.6               3.4                1.4               0.3
#
#         class
# 0  versicolor
# 1   virginica
# 2  versicolor
# 3  versicolor
# 4      setosa
