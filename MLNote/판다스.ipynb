# %%
import pandas as pd

# %%
file_url = 'sample.csv'

# %%
sample = pd.read_csv(file_url)

# %%
sample
# Out:
#     Var_1  Var_2
# 0       1      2
# 1       3      4
# 2       2      5
# 3       5      6
# 4       3      2
# 5       1      1
# 6       2      6
# 7       5      7
# 8       6      8
# 9       7      4
# 10      7      7
# 11      8      3
# 12      9      7
# 13      3      9
# 14      2      2
# 15      1      3
# 16      2      6
# 17      2      4
# 18      3      3

# %%
sample.head()
# Out:
#    Var_1  Var_2
# 0      1      2
# 1      3      4
# 2      2      5
# 3      5      6
# 4      3      2

# %%
sample.head(3)
# Out:
#    Var_1  Var_2
# 0      1      2
# 1      3      4
# 2      2      5

# %%
sample.tail()
# Out:
#     Var_1  Var_2
# 14      2      2
# 15      1      3
# 16      2      6
# 17      2      4
# 18      3      3

# %%
sample.tail(10)
# Out:
#     Var_1  Var_2
# 9       7      4
# 10      7      7
# 11      8      3
# 12      9      7
# 13      3      9
# 14      2      2
# 15      1      3
# 16      2      6
# 17      2      4
# 18      3      3

# %%
sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Var_1   19 non-null     int64
#  1   Var_2   19 non-null     int64
# dtypes: int64(2)
# memory usage: 432.0 bytes

# %%
sample.describe()
# Out:
#            Var_1      Var_2
# count  19.000000  19.000000
# mean    3.789474   4.684211
# std     2.529360   2.310667
# min     1.000000   1.000000
# 25%     2.000000   3.000000
# 50%     3.000000   4.000000
# 75%     5.500000   6.500000
# max     9.000000   9.000000

# %%
sample_dic = {'name' : ['이순신', '신사임당', '이성계'], 'age' : [23, 22, 21]}
pd.DataFrame(sample_dic)
# Out:
#    name  age
# 0   이순신   23
# 1  신사임당   22
# 2   이성계   21

# %% [markdown]
# ### 컬럼명과 인덱스명을 별도로 지정해보기

# %%
[[1, 2],
 [3, 4],
 [5, 6],
 [7, 8]]
# Out:
# [[1, 2], [3, 4], [5, 6], [7, 8]]

# %%
pd.DataFrame([[1, 2], [3, 4], [5, 6], [7, 8]])
# Out:
#    0  1
# 0  1  2
# 1  3  4
# 2  5  6
# 3  7  8

# %%
pd.DataFrame([[1, 2], [3, 4], [5, 6], [7, 8]], columns=['var_1', 'var_2'], index=['a', 'b', 'c', 'd'])
# Out:
#    var_1  var_2
# a      1      2
# b      3      4
# c      5      6
# d      7      8
